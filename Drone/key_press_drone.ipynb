# %%
import time
import cv2 as cv
from easytello import tello
from tkinter import*
import keyboard

my_drone = tello.Tello()

while True:
    if keyboard.is_pressed('a'):
        my_drone.takeoff()
        #time.sleep(3)
    elif keyboard.is_pressed('f'):
        my_drone.forward(30)
        #time.sleep(3)
    elif keyboard.is_pressed('b'):
        my_drone.back(30)
        #time.sleep(3)
    elif keyboard.is_pressed('u'): #up
        my_drone.up(30)
        #time.sleep(3)
    elif keyboard.is_pressed('d'): #Down
        my_drone.down(30)
        #time.sleep(3)
    elif keyboard.is_pressed('l'): #left
        my_drone.left(30)
        #time.sleep(3)
    elif keyboard.is_pressed('r'): #right
        my_drone.right(30)
        #time.sleep(3)
    elif keyboard.is_pressed('z'): #land
        my_drone.land()
    elif keyboard.is_pressed('c'): #clockwise rotataion
        my_drone.cw(15)
    elif keyboard.is_pressed('o'): #counter clockwise rotataion
        my_drone.ccw(15)
    elif keyboard.is_pressed('i'): #counter clockwise rotataion
        my_drone.flip(15)
        
    

#my_drone = tello.Tello()
#my_drone.takeoff()
#my_drone.up()
# Out:
# Sending command: command
# Response: b"\xccp\x08\t\x88P\x10\x87\x08\x199\x00'\x00\x00\x00\x03\x00\x00\x00*\x00\x00\x00\x00\x00\x00\x00BUILD May  7 2019 12:02:11\x00\x00\x00\x00\x00\x00F\xc3#\x00\x07\x00\x00\x00\x00\x03e\x01\x1b\x1b\x1d`\x12ee\x17ecmbUU\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaa\xaaUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUDJI_LOG_V3\xb6g\xa2@\x8e\x17"
# Sending command: takeoff
# Response: b'ok'
# Sending command: forward 30
# Response: b'ok'
# Sending command: forward 30
# Response: b'ok'
# Sending command: forward 30
# Response: b'ok'
# Sending command: forward 30
# Response: b'ok'
# Sending command: forward 30
# Response: b'ok'
# Sending command: right 30
# Response: b'ok'
# Sending command: right 30
# Response: b'ok'
# Sending command: right 30
# Response: b'ok'
# Sending command: right 30
# Response: b'ok'
# Sending command: back 30
# Response: b'ok'
# Sending command: back 30
# Response: b'ok'
# Sending command: back 30
# Response: b'ok'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: cw 15
# Response: b'ok'
# Sending command: cw 15
# Response: b'ok'
# Sending command: cw 15
# Response: b'ok'
# Sending command: cw 15
# Response: b'ok'
# Sending command: cw 15
# Response: b'ok'
# Sending command: cw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: flip 15
# Response: b'unknown command: 15'
# Sending command: back 30
# Response: b'ok'
# Sending command: back 30
# Response: b'ok'
# Sending command: left 30
# Response: b'ok'
# Sending command: left 30
# Response: b'ok'
# Sending command: left 30
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: ccw 15
# Response: b'ok'
# Sending command: right 30
# Response: b'ok'
# Sending command: left 30
# Response: b'ok'
# Sending command: forward 30
# Response: b'ok'
